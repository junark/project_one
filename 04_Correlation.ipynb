# %%
import pandas as pd
import scipy.stats as stats
import warnings
warnings.filterwarnings('ignore')

# %%
csvfile = "correlation.csv"
df = pd.read_csv(csvfile)
df
# Out:
#              State State Ab.   State Capital Population    ORI Code  \
# 0          ALABAMA        AL      Montgomery    198,525   AL0030100
# 1           ALASKA        AK          Juneau     32,113   AK0010300
# 2          ARIZONA        AZ         Phoenix  1,680,992   AZ0072300
# 3         ARKANSAS        AR     Little Rock    197,312   AR0600200
# 4       CALIFORNIA        CA      Sacramento    513,624   CA0340400
# 5         COLORADO        CO          Denver    727,211   CODPD0000
# 6      CONNECTICUT        CT        Hartford    122,105   CT0006400
# 7         DELAWARE        DE           Dover     38,079   DE0010100
# 8          FLORIDA        FL     Tallahassee    194,500   FL0370300
# 9          GEORGIA        GA         Atlanta    506,811   GAAPD0000
# 10          HAWAII        HI        Honolulu    345,064   HI0020000
# 11           IDAHO        ID           Boise    228,959   ID0010100
# 12        ILLINOIS        IL     Springfield    114,230   IL0840200
# ...

# %%
corr_df = df.corr()
corr_df
# Out:
#                              Num_Officers  Total_Crimes  School_Ratings  \
# Num_Officers                     1.000000      0.900024       -0.015123
# Total_Crimes                     0.900024      1.000000       -0.074269
# School_Ratings                  -0.015123     -0.074269        1.000000
# Unemployment_Rate                0.045965      0.029864       -0.094481
# Avg_Income                       0.084469      0.076492        0.029413
# Crimes(R,SA,SP) Per Citizen     -0.106311      0.098801       -0.077219
#
#                              Unemployment_Rate  Avg_Income  \
# Num_Officers                          0.045965    0.084469
# Total_Crimes                          0.029864    0.076492
# School_Ratings                       -0.094481    0.029413
# Unemployment_Rate                     1.000000   -0.013991
# Avg_Income                           -0.013991    1.000000
# Crimes(R,SA,SP) Per Citizen          -0.010716    0.317350
#
# ...

# %%
corr_df.to_csv("correlation_result.csv", index=False, header=True)
